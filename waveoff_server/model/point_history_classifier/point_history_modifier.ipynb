# %%
import pandas as pd

# Load the file to examine its structure
file_path = 'C:/Postgrad/Courses/Fall_2024/6907 Advanced Interaction Techniques/Project/hand-gesture-recognition-mediapipe-main - Copy 1/model/point_history_classifier/point_history.csv'
data = pd.read_csv(file_path, header = None)

# Display the first few rows to understand its structure
data.head()
# Out:
#    0   1   2         3         4         5         6         7         8   \
# 0   0   0   0 -0.265625  0.152083 -0.204687 -0.047917 -0.140625 -0.100000
# 1   0   0   0 -0.265625  0.150000 -0.201563 -0.050000 -0.137500 -0.102083
# 2   0   0   0 -0.265625  0.150000 -0.201563 -0.050000 -0.135937 -0.100000
# 3   0   0   0 -0.265625  0.150000 -0.201563 -0.047917 -0.135937 -0.100000
# 4   0   0   0 -0.265625  0.150000 -0.201563 -0.047917 -0.137500 -0.100000
#
#          9   ...        23        24        25        26        27   28  \
# 0 -0.071875  ... -0.265625  0.152083 -0.203125 -0.047917 -0.137500 -0.1
# 1 -0.071875  ... -0.265625  0.150000 -0.201563 -0.047917 -0.135937 -0.1
# 2 -0.071875  ... -0.265625  0.150000 -0.201563 -0.047917 -0.137500 -0.1
# 3 -0.070312  ... -0.265625  0.150000 -0.201563 -0.047917 -0.137500 -0.1
# 4 -0.071875  ... -0.265625  0.150000 -0.201563 -0.047917 -0.137500 -0.1
#
#          29        30   31   32
# 0 -0.071875 -0.079167  0.0  0.0
# ...

# %%
# The first column appears to be the first column named as '0' in this dataset.
# I'll perform the transformation requested: change 0s to 1s, 1s to 2s, etc., in the first column.

# Increment each value by 1 in the first column
data[0] = data[0] + 1

# Save the updated file and display it to the user
updated_file_path = 'C:/Postgrad/Courses/Fall_2024/6907 Advanced Interaction Techniques/Project/hand-gesture-recognition-mediapipe-main - Copy 1/model/point_history_classifier/point_history_updated.csv'
data.to_csv(updated_file_path, index=False)

updated_file_path
# Out:
# 'C:/Postgrad/Courses/Fall_2024/6907 Advanced Interaction Techniques/Project/hand-gesture-recognition-mediapipe-main - Copy 1/model/point_history_classifier/point_history_updated.csv'
